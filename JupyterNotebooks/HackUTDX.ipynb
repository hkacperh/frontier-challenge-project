# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from joblib import dump, load
from sklearn.decomposition import PCA
import numpy as np
from sklearn.model_selection import GridSearchCV

# %%
def convert_to_int(value):
    try:
        return float(value)  # Convert numeric values to int
    except:
        return sum(ord(char) for char in value)

##logreg = load('jame.joblib') 

A=pd.read_csv('/Users/az/Desktop/training_data.csv')
A = A.applymap(convert_to_int)
B=pd.DataFrame()


B=A
'''
B = B.applymap(convert_to_int)

i=0
num = 0

B= B.fillna(0)

for index, row in A.iterrows():
    if row['service_repair'] == 1:
        num+=1
        B=B.append(row, ignore_index=True)
        if (len(B)>2000):break
    i+=1

i=0
for index, row in A.iterrows():
    
    if row['service_repair'] != 1:
        B=B.append(row, ignore_index=True)
        #if (len(B)>3000):break
    i+=1 
'''
C=B.loc[:,['service_repair']]
C= C.fillna(0)


columns_to_drop = ['Customer', 'clli','objectName','service_repair','objectType','REPORT_DATE']
B = B.drop(columns_to_drop,axis=1)
B= B.fillna(0)
# Out:
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/3566483941.py:9: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   A=pd.read_csv('/Users/az/Desktop/training_data.csv')

# %%
scaler = StandardScaler()
scaler.fit(B)
scaled_data = scaler.transform(B)
pca = PCA(n_components=15)
pca.fit(scaled_data)
x_pca = pca.transform(scaled_data)

# %%
X_train,X_test, Y_train, Y_test = train_test_split (x_pca,C, test_size=0.3,random_state =21)

# %%
weights = np.linspace(0.05, 0.95, 20)
gsc = GridSearchCV(
    estimator=LogisticRegression(),
    param_grid={
        'class_weight': [{0: x, 1: 1.0-x} for x in weights]
    },
    scoring='f1',
    cv=5
)

grid_result = gsc.fit(X_train, Y_train)
print("Best parameters : %s" % grid_result.best_params_)
;
# Out:
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best parameters : {'class_weight': {0: 0.05, 1: 0.95}}
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ''

# %%
clf = LogisticRegression(**grid_result.best_params_).fit(X_train, Y_train)
clf.score(X_train,Y_train)
# Out:
# /Users/az/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9302409856858126

# %%
#clf = load('jame1.joblib')
clf.score(X_test,Y_test)
# Out:
# 0.9314590709718332

# %%
#log_reg=load('jame.joblib')
#log_reg=LogisticRegression(random_state = 0).fit(x_pca, C)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 log_reg=load('jamee.joblib')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:579, in load(filename, mmap_mode)
#     577         obj = _unpickle(fobj)
#     578 else:
# --> 579     with open(filename, 'rb') as f:
#     580         with _read_fileobject(f, filename, mmap_mode) as fobj:
#     581             if isinstance(fobj, str):
#     582                 # if the returned file object is a string, this means we
#     583                 # try to load a pickle file generated with an version of
#     584                 # Joblib so we load it with joblib compatibility function.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'jamee.joblib'

# %%
log_reg.score(x_pca,C)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [64], in <cell line: 1>()
# ----> 1 log_reg.score(x_pca,C)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:651, in ClassifierMixin.score(self, X, y, sample_weight)
#     626 """
#     627 Return the mean accuracy on the given test data and labels.
#     628
#    (...)
#     647     Mean accuracy of ``self.predict(X)`` wrt. `y`.
#     648 """
#     649 from .metrics import accuracy_score
# --> 651 return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:425, in LinearClassifierMixin.predict(self, X)
#     411 def predict(self, X):
#     412     """
#     413     Predict class labels for samples in X.
#     414
#    (...)
#     423         Vector containing the class labels for each sample.
#     424     """
# --> 425     scores = self.decision_function(X)
#     426     if len(scores.shape) == 1:
#     427         indices = (scores > 0).astype(int)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:407, in LinearClassifierMixin.decision_function(self, X)
#     387 """
#     388 Predict confidence scores for samples.
#     389
#    (...)
#     403     this class would be predicted.
#     404 """
#     405 check_is_fitted(self)
# --> 407 X = self._validate_data(X, accept_sparse="csr", reset=False)
#     408 scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     409 return scores.ravel() if scores.shape[1] == 1 else scores
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:585, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     582     out = X, y
#     584 if not no_val_X and check_params.get("ensure_2d", True):
# --> 585     self._check_n_features(X, reset=reset)
#     587 return out
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:400, in BaseEstimator._check_n_features(self, X, reset)
#     397     return
#     399 if n_features != self.n_features_in_:
# --> 400     raise ValueError(
#     401         f"X has {n_features} features, but {self.__class__.__name__} "
#     402         f"is expecting {self.n_features_in_} features as input."
#     403     )
#
# ValueError: X has 20 features, but LogisticRegression is expecting 40 features as input.

# %%
#from joblib import dump, load
dump(clf, 'jame.joblib')
# Out:
# ['jame.joblib']

# %%
n=500
def convert_to_int(value):
    try:
        return float(value)  # Convert numeric values to int
    except:
        return sum(ord(char) for char in value)

    
    
A=pd.read_csv('/Users/az/Desktop/training_data.csv')
A = A.applymap(convert_to_int)
B=pd.DataFrame()


#B=A

B = B.applymap(convert_to_int)



B= B.fillna(0)
i=0

for index, row in A.iterrows():
    if row['service_repair'] == 1:
        B=B.append(row, ignore_index=True)
        if (len(B)>n):break
    i+=1

i=0
for index, row in A.iterrows():
    
    if row['service_repair'] != 1:
        B=B.append(row, ignore_index=True)
        if (len(B)>(n*3)):break
    i+=1


B = B.applymap(convert_to_int)

i=0
B= B.fillna(0)


C=B.loc[:,['service_repair']]
C= C.fillna(0)


columns_to_drop = ['Customer', 'clli','objectName','service_repair','objectType','REPORT_DATE']
B = B.drop(columns_to_drop,axis=1)
B= B.fillna(0)
scaler = StandardScaler()
scaler.fit(B)
scaled_data = scaler.transform(B)
pca = PCA(n_components=15)
pca.fit(scaled_data)
x_pca = pca.transform(scaled_data)
;
# Out:
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:10: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   A=pd.read_csv('/Users/az/Desktop/training_data.csv')
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# ...
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# /var/folders/tc/3zj6b_yn0db6yslr5bqvsvm00000gn/T/ipykernel_42550/4279560184.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   B=B.append(row, ignore_index=True)
# ''

# %%
log_reg=load('jame.joblib')
log_reg.score(x_pca,C)
# Out:
# 0.676215856095936
